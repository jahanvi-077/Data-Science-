# %%
import os
print("os learning")
# Out:
# os learning

# %%
file = os.getcwd()
print("current working directory:-",file)
# Out:
# current working directory:- d:\Data Science\Data-Science-\pandas

# %%
file = os.listdir()
print("no. of files in my directory is:-",file)
# Out:
# no. of files in my directory is:- ['practice.ipynb', 'Used_Bikes (1).csv']
