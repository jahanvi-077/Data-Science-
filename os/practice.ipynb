# %%
import os 
print("os file")
# Out:
# os file

# %%
file = os.getcwd()
print("my current working directory is :-",file)
# Out:
# my current working directory is :- d:\Data Science\Data-Science-\os

# %%
file = os.listdir()
print("the list of all files in my current working direcory:-",file)
# Out:
# the list of all files in my current working direcory:- ['basic_os.ipynb', 'practice.ipynb']

# %%
file = os.listdir("D:\Data Science\Data-Science-\pandas")
print("list of all the files in this folder :-",file)
# Out:
# list of all the files in this folder :- ['practice.ipynb', 'Used_Bikes (1).csv']

# %%
os.mkdir("create_new_folder")
print("folder created successfully")
# Out:
# folder created successfully

# %%
os.rename("create_new_folder","practicing os")
print("changed name of folder is practicing os")
# Out:
# changed name of folder is practicing os

# %%
os.rmdir("new_folder")
print("this directory is removed")
# Out:
# this directory is removed

# %%
os.environ.get("D:\Data Science\Data-Science-\pandas")

# %%
os.path.file("D:\Games")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 os.path.file("D:\Games")
#
# AttributeError: module 'ntpath' has no attribute 'file'

# %%
os.path.isfile("D:\Games\Grand Theft Auto V\GTAV.HeapAdjuster.asi")
# Out:
# True

# %%
os.path.getsize("D:\Program Files")
# Out:
# 0

# %%
os.path.getsize("D:\TEKKEN 7 [FitGirl Repack]")
# Out:
# 4096

# %%
os.listdir("D:\TEKKEN 7 [FitGirl Repack]")
# Out:
# ['MD5',
#  'setup-fitgirl-01.bin',
#  'setup-fitgirl-02.bin',
#  'setup-fitgirl-03.bin',
#  'setup-fitgirl-04.bin',
#  'setup-fitgirl-05.bin',
#  'setup-fitgirl-06.bin',
#  'setup-fitgirl-07.bin',
#  'setup-fitgirl-08.bin',
#  'setup-fitgirl-09.bin',
#  'setup-fitgirl-10.bin',
#  'setup-fitgirl-11.bin',
#  'setup-fitgirl-optional-credits-video.bin',
#  'setup-fitgirl-optional-gallery-videos-2.bin',
#  'setup-fitgirl-optional-gallery-videos.bin',
#  'setup-fitgirl-optional-opening-video.bin',
#  'setup-fitgirl-optional-story-videos.bin',
#  'setup.exe',
#  'Verify BIN files before installation.bat']

# %%
path1 = r'D:\Data Science'
path2 = r'Data-Science-\Python'
complete_path = os.path.join(path1,path2)

# %%
complete_path
# Out:
# 'D:\\Data Science\\Data-Science-\\Python'

# %%
os.listdir(complete_path)
# Out:
# ['basic.py',
#  'c++',
#  'conditional_statement.ipynb',
#  'daa practical.py',
#  'encapsulation.ipynb',
#  'gittty',
#  'gittty.py',
#  'Inheritance.ipynb',
#  'janvipractice.py',
#  'looping.ipynb',
#  'practiceencap.ipynb',
#  'python.ipynb']

# %%
path = os.getcwd()
print("before,",path)
os.chdir(r'D:\Data Science\Data-Science-\pandas')
print("after,",os.getcwd())
# Out:
# before, D:\Data Science
# after, D:\Data Science\Data-Science-\pandas

# %%
class Student:
    def __init__(self):
        pass

# %%
class Student:
    def __init__(self):
        self.name = "govind" ### intance variable 
        self.age = 23
        self.addres = "jaipur rajasthan"

obj =Student()

# %%
obj.name
# Out:
# 'govind'

# %%
obj.age
# Out:
# 23

# %%
class Collage:
    def __init__(self,name , address , account ):
        self.collage_name = name 
        self.collage_address = address
        self.account_number = account
cl_obj=Collage(name="jecrc",address="sitapura jaipur", account=15151)
cl_obj.account_number
# Out:
# 15151

# %%
cl_obj.collage_address
# Out:
# 'sitapura jaipur'

# %%
class Collage:
    def __init__(self,name, address , account ):
        self.collage_name = name 
        self.collage_address = address
        self.account_number = account
cl_obj=Collage(name="jecrc",address="sitapura jaipur", account=15151)
cl_obj.account_number

# %%
class Student:
    def __init__(self,name,address,account):
        self.collage_name = name 
        self.collage_address = address
        self.account_number = account
    def game(self):
        print(f"accessing the variables {self.collage_address}")
        print(f"accessing the variables {self.collage_name}")
        print(f"accessing the variables {self.account_number}")
cl_obj = Student(name = "jerc",address = "jaipur", account = 2334)
cl_obj.game()
# Out:
# accessing the variablesjaipur
# accessing the variablesjerc
# accessing the variables2334

# %%
class Student:
    def __init__(self,name,address,account):
        self.collage_name = name 
        self.collage_address = address
        self.account_number = account
    def game(self):
        print(f"accessing the variables {self.collage_address}")
        print(f"accessing the variables {self.collage_name}")
        print(f"accessing the variables {self.account_number}")   
class Collage(Student):
    pass
        # def __init__(self):
        #      self.branch = "3rd year"

             
    
           
        # self.student_name = name
        # self.student_age = age
        
    # def temp(self):
    #     print(f"accessing the variables {self.student_age}")
    #     print(f"accessing the variables {self.student_name}") 

# h =Student(name="jaanvi", address="jaipur", account=5155)
cl =Collage(name='kjgnkjfg',address="kdb",account='jfg')

# %%
cl.account_number
# Out:
# 'jfg'
