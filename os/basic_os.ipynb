# %%
  
import os 
print("Os module")
# Out:
# Os module

# %%
file =os.getcwd() # current working directory 
print("current working directory:-",file)
# Out:
# current working directory:- d:\Data Science\Data-Science-\os

# %%
file =os.listdir()
print("total list os current directory:-",file)
# Out:
# total list os current directory:- ['basic_os.ipynb', 'new_folder', 'practice.ipynb', 'testing']

# %%
os.listdir("D:\TEKKEN 7 [FitGirl Repack]")
# Out:
# ['MD5',
#  'setup-fitgirl-01.bin',
#  'setup-fitgirl-02.bin',
#  'setup-fitgirl-03.bin',
#  'setup-fitgirl-04.bin',
#  'setup-fitgirl-05.bin',
#  'setup-fitgirl-06.bin',
#  'setup-fitgirl-07.bin',
#  'setup-fitgirl-08.bin',
#  'setup-fitgirl-09.bin',
#  'setup-fitgirl-10.bin',
#  'setup-fitgirl-11.bin',
#  'setup-fitgirl-optional-credits-video.bin',
#  'setup-fitgirl-optional-gallery-videos-2.bin',
#  'setup-fitgirl-optional-gallery-videos.bin',
#  'setup-fitgirl-optional-opening-video.bin',
#  'setup-fitgirl-optional-story-videos.bin',
#  'setup.exe',
#  'Verify BIN files before installation.bat']

# %%
os.mkdir("New_folder") # creating folder
print("folder created successfully")
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 os.mkdir("New_folder") # creating folder
#       2 print("folder created successfully")
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'New_folder'

# %%
os.rename("Data science","New_folder")
print("folder renamed successfully")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 os.rename("Data science","New_folder")
#       2 print("folder renamed successfully")
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'Data science' -> 'New_folder'

# %%
os.listdir()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 os.listdir()
#
# NameError: name 'os' is not defined

# %%
os.rmdir("demo")

# %%
os.rmdir("New_folder") # removing folder
print("folder removed successfully")
# Out:
# folder removed successfully

# %%
os.listdir()
# Out:
# ['basic_os.ipynb']

# %%
os.remove("poet.txt") # removing file
print("file removed successfully")
# Out:
# file removed successfully

# %%
file =os.getcwd() # current working directory 
print("current working directory:-",file)
# Out:
# current working directory:- d:\Data Science\Data-Science-\os

# %%
file
# Out:
# 'd:\\Data Science\\Data-Science-\\os'

# %%
result =os.environ.get(file)

# %%
print(result)
# Out:
# None

# %%
os.path.isfile("D:\TEKKEN 7 [FitGirl Repack]\setup-fitgirl-06.bin")
# Out:
# True

# %%
os.path.isdir("D:\TEKKEN 7 [FitGirl Repack]\govind")
# Out:
# False

# %%
result = os.environ.get('D:\Data Science')

# %%
path1 =r'D:\Program Files\Microvirt'
path2 = r'MEmuHyperv\netflt'

# %%
complete_path =os.path.join(path1,path2)

# %%
os.listdir(complete_path)
# Out:
# ['MEmuNetFlt.cat',
#  'MEmuNetFlt.inf',
#  'MEmuNetFlt.sys',
#  'MEmuNetFltM.inf',
#  'MEmuNetFltNobj.dll']

# %%
path =os.getcwd()
print("before ",path)
os.chdir(r'D:\Data Science\Data-Science-\os')
print("after ",os.getcwd())
# Out:
# before  D:\Data Science\Data-Science-\python
# after  D:\Data Science\Data-Science-\os
