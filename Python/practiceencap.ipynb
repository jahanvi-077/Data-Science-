# %%
#public class declarations
class Collage:
    collage_name = "jecrc"
    collage_branch = "cse"
st_obj = Collage()
print(st_obj.collage_name)
print(st_obj.collage_branch)
# Out:
# jecrc
# cse

# %%
#private variable declarations
class Student:
    __student_name = "raveena"
    __student_branch = "Btech"
    __student_class = "3rd year"
st_obj = Student()    
st_obj.__student_branch
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 7
#       5     __student_class = "3rd year"
#       6 st_obj = Student()
# ----> 7 st_obj.__student_branch
#
# AttributeError: 'Student' object has no attribute '__student_branch'

# %%
#protected class declarations
class Collage:
    _collage_name = "jecrc"
    _collage_branch = "cse"
st_obj = Collage()
print(st_obj._collage_name)
print(st_obj._collage_branch)
# Out:
# jecrc
# cse

# %%
#how  to access protected using method creation
class Student:
    _student_name = "raveena"
    _student_branch = "Btech"
    _student_class = "3rd year"
    def name(self):
      print(f"my name is {self._student_name}")  
st_obj = Student()
st_obj.name() 
# st_obj._student_class  
# st_obj._student_name
# Out:
# my name is raveena

# %%
#how to access private variables using method creation
class Student:
    __student_name = "raveena"
    __student_branch = "Btech"
    __student_class = "3rd year"
    def name(self):
      print(f"my name is {self.__student_name}")  
st_obj = Student()
st_obj.name()
# Out:
# my name is raveena
